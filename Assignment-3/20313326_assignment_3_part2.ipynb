# %% [markdown]
# ### Please check 20313326_assignment_3_bonus.ipynb for Hyperparemeter Tunning Report

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.models import load_model

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# Download the CIFAR-10 dataset from Keras library

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %% [markdown]
# Split original training data to training and test and validation sets

# %%
# Split the training set into 80% training and 20% validation
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# %%
print('Train Images Shape:      ', X_train.shape)
print('Train Labels Shape:      ', y_train.shape)

print('\nValidation Images Shape: ', X_val.shape)
print('Validation Labels Shape: ', y_val.shape)

print('\nTest Images Shape:       ', X_test.shape)
print('Test Labels Shape:       ', y_test.shape)
# Out:
# Train Images Shape:       (40000, 32, 32, 3)
# Train Labels Shape:       (40000, 1)
#
# Validation Images Shape:  (10000, 32, 32, 3)
# Validation Labels Shape:  (10000, 1)
#
# Test Images Shape:        (10000, 32, 32, 3)
# Test Labels Shape:        (10000, 1)

# %% [markdown]
# Data Normalization (from [0, 255] to [0, 1])

# %%
# Normalize pixel values to [0, 1]
X_train = X_train.astype('float32') / 255.0
X_val = X_val.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# Print shapes to verify
print(f"X_train shape: {X_train.shape}")
print(f"X_val shape: {X_val.shape}")
print(f"X_test shape: {X_test.shape}")
# Out:
# X_train shape: (40000, 32, 32, 3)
# X_val shape: (10000, 32, 32, 3)
# X_test shape: (10000, 32, 32, 3)

# %% [markdown]
# Convert the class labels to one-hot vectors to transform the categorical labels into a format suitable for multi-class classification by neural networks:

# %%
# Transform target variable into one-hotencoding
y_category_train = to_categorical(y_train, 10)
y_category_val = to_categorical(y_val, 10)
y_category_test = to_categorical(y_test, 10)

# %% [markdown]
# ### Enhanced version of Conv2 Architecture, using lower learning rate, higher model depth and Adam optimizer
#
# Model inspired by VGG 16, further enhanced architecture please see part 2 of the assignment
#
# The Model included the following techniques:
#
# - Conv2D layers
# - Batch Normalization
# - regularization
# - MaxPool2D layer
# - Dropout layer
# - Flatten layer
# - Dense layer
# - softmax activation function
# - ReLU activation function

# %%
INPUT_SHAPE = (32, 32, 3)
KERNEL_SIZE = (3, 3)
model = Sequential()

# Convolutional Layer
model.add(Conv2D(filters=32, kernel_size=KERNEL_SIZE, input_shape=INPUT_SHAPE, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(filters=32, kernel_size=KERNEL_SIZE, activation='relu', padding='same'))
model.add(BatchNormalization())
# Pooling layer
model.add(MaxPool2D(pool_size=(2, 2)))
# Dropout layers
model.add(Dropout(0.25))

model.add(Conv2D(filters=64, kernel_size=KERNEL_SIZE, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(filters=64, kernel_size=KERNEL_SIZE, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(filters=128, kernel_size=KERNEL_SIZE, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(filters=128, kernel_size=KERNEL_SIZE, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
# model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(10, activation='softmax'))

# Define optimizer with specific learning rate
optimizer = tf.keras.optimizers.Adam(learning_rate=0.005)

# Compile the model with the updated optimizer
METRICS = [
    'accuracy',
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall')
]
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=METRICS)

# %% [markdown]
# Data Augmentation:
#
# Expand the size of the training set by creating modified versions of images in the dataset
#
# The choice of data augmentation techniques often depends on the specific characteristics of the dataset, and CIFAR-10 dataset comprises small color images of objects from 10 different classes.
#
# Given the nature of these images, some augmentation techniques are more applicable by the following:
#
# - Width and Height shift: Small shifts can help the model become invariant to the position of the object in the image
# - Rotation: A small degree of rotation can help the model become invariant to the orientation of the object
# - Horizontal Flip: A horizontal flip because for many images, the object of interest remains the same when flipped horizontally
# - Zoom: Small zooming can also help the model generalize better
# - Brightness Range: Changing brightness can simulate various lighting conditions (brigtness change make the model training hard to improve)
#
# The above techniques are expected to help improve the robustness and generalization capability of the model

# %%
data_generator = ImageDataGenerator(
    width_shift_range=0.1,

    rotation_range=10,

    # zoom_range=0.1,

    # brightness_range=[0.9,1.1],

    # shear_range=10,

    height_shift_range=0.1, 

    horizontal_flip=True    
)

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)

# %% [markdown]
# Included early stop techniques for model training, patience 10

# %%
batch_size = 32
train_generator = data_generator.flow(X_train, y_category_train, batch_size)
steps_per_epoch = X_train.shape[0] // batch_size

Eval = model.fit(train_generator, 
                 epochs=50,
                 steps_per_epoch=steps_per_epoch,
                 validation_data=(X_val, y_category_val), 
                 callbacks=[early_stop]
               )
# Out:
# Epoch 1/50
# 1250/1250 [==============================] - 134s 105ms/step - loss: 1.9513 - accuracy: 0.2711 - precision: 0.4867 - recall: 0.0644 - val_loss: 1.5915 - val_accuracy: 0.4011 - val_precision: 0.6566 - val_recall: 0.1348
# Epoch 2/50
# 1250/1250 [==============================] - 127s 101ms/step - loss: 1.5834 - accuracy: 0.4100 - precision: 0.6212 - recall: 0.2023 - val_loss: 1.2714 - val_accuracy: 0.5408 - val_precision: 0.6997 - val_recall: 0.3926
# Epoch 3/50
# 1250/1250 [==============================] - 128s 103ms/step - loss: 1.3391 - accuracy: 0.5237 - precision: 0.6972 - recall: 0.3419 - val_loss: 1.1601 - val_accuracy: 0.5868 - val_precision: 0.7154 - val_recall: 0.4569
# Epoch 4/50
# 1250/1250 [==============================] - 130s 104ms/step - loss: 1.1789 - accuracy: 0.5886 - precision: 0.7433 - recall: 0.4370 - val_loss: 1.4701 - val_accuracy: 0.5737 - val_precision: 0.6553 - val_recall: 0.5151
# Epoch 5/50
# ...

# %% [markdown]
# Visualizing the training and validation loss, accuracy evolution and f1 score base on precision and recall over epochs using model history:

# %%
# Calculate F1 score for training and validation
f1_train = [
    2 * (p * r) / (p + r) if (p + r) > 0 else 0 
    for p, r in zip(Eval.history['precision'], Eval.history['recall'])
]
f1_val = [
    2 * (p * r) / (p + r) if (p + r) > 0 else 0 
    for p, r in zip(Eval.history['val_precision'], Eval.history['val_recall'])
]

# Plotting
plt.figure(figsize=(12, 16))

# Loss plot
plt.subplot(4, 2, 1)
plt.plot(Eval.history['loss'], label='Loss')
plt.plot(Eval.history['val_loss'], label='val_Loss')
plt.title('Loss Function Evolution')
plt.legend()

# Accuracy plot
plt.subplot(4, 2, 2)
plt.plot(Eval.history['accuracy'], label='accuracy')
plt.plot(Eval.history['val_accuracy'], label='val_accuracy')
plt.title('Accuracy Function Evolution')
plt.legend()

# Precision plot
plt.subplot(4, 2, 3)
plt.plot(Eval.history['precision'], label='precision')
plt.plot(Eval.history['val_precision'], label='val_precision')
plt.title('Precision Function Evolution')
plt.legend()

# Recall plot
plt.subplot(4, 2, 4)
plt.plot(Eval.history['recall'], label='recall')
plt.plot(Eval.history['val_recall'], label='val_recall')
plt.title('Recall Function Evolution')
plt.legend()

# F1 Score plot
plt.subplot(4, 2, 5)
plt.plot(f1_train, label='F1 Score')
plt.plot(f1_val, label='val_F1 Score')
plt.title('F1 Score Evolution')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Confusion Matrix for classification after model training

# %%
evaluation = model.evaluate(X_test, y_category_test)
print(f'Test Accuracy : {evaluation[1] * 100:.2f}%')

y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(y_test, y_pred)


disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=lables)


# NOTE: Fill all variables here with default values of the plot_confusion_matrix
fig, ax = plt.subplots(figsize=(10, 10))
disp = disp.plot(xticks_rotation='vertical', ax=ax,cmap='inferno')

plt.show()
# Out:
# 313/313 [==============================] - 7s 22ms/step - loss: 0.5673 - accuracy: 0.8207 - precision: 0.8811 - recall: 0.7752
# Test Accuracy : 82.07%
# 313/313 [==============================] - 7s 21ms/step

# %% [markdown]
# Classification Report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.83      1000
#            1       0.93      0.93      0.93      1000
#            2       0.78      0.72      0.75      1000
#            3       0.69      0.65      0.67      1000
#            4       0.78      0.83      0.81      1000
#            5       0.87      0.62      0.72      1000
#            6       0.82      0.87      0.84      1000
#            7       0.78      0.90      0.84      1000
#            8       0.90      0.91      0.91      1000
#            9       0.88      0.90      0.89      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.82      0.82      0.82     10000
# weighted avg       0.82      0.82      0.82     10000

# %% [markdown]
# Performance check on one single image classification

# %%
my_image = X_test[50]
plt.imshow(my_image)

# that's a Deer
print(f" Image 50 is {y_test[50]}")

# correctly predicted as a Deer
pred_100 = np.argmax(model.predict(my_image.reshape(1, 32, 32, 3)))
print(f"The model predict that image 50 is {pred_100}")
# Out:
#  Image 50 is [9]
# 1/1 [==============================] - 0s 23ms/step
# The model predict that image 50 is 9

# %% [markdown]
# Bulk Performance check

# %%
# CIFAR-10 classes
lables = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
               
# Create a new figure
plt.figure(figsize=(15,15))

# Loop over the first 25 images
for i in range(64):
    # Create a subplot for each image
    plt.subplot(8, 8, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)

    # Display the image
    plt.imshow(X_test[i])

    # Set the label as the title
    plt.title(lables[y_test[i][0]], fontsize=12)

# Display the figure
plt.show()

# %%
def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array, true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel(f"{lables[int(predicted_label)]} {100*np.max(predictions_array):2.0f}% ({lables[int(true_label)]})", 
               color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array, int(true_label[i])
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %% [markdown]
# Plot the first 40 test images, their predicted labels, and the true labels
#
# Color correct predictions in blue and incorrect predictions in red

# %%
predictions = model.predict(X_test)

# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 8
num_cols = 5
num_images = num_rows * num_cols
plt.figure(figsize=(2 * 2 * num_cols, 2 * num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2 * num_cols, 2 * i + 1)
    plot_image(i, predictions[i], y_test, X_test)
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i, predictions[i], y_test)
plt.tight_layout()
plt.show()
# Out:
# 313/313 [==============================] - 6s 20ms/step
