# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow
from tensorflow.keras.datasets import cifar10
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.models import load_model

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
# Split the training set into 80% training and 20% validation
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# %%
print('Train Images Shape:      ', X_train.shape)
print('Train Labels Shape:      ', y_train.shape)

print('\nValidation Images Shape: ', X_val.shape)
print('Validation Labels Shape: ', y_val.shape)

print('\nTest Images Shape:       ', X_test.shape)
print('Test Labels Shape:       ', y_test.shape)
# Out:
# Train Images Shape:       (40000, 32, 32, 3)
# Train Labels Shape:       (40000, 1)
#
# Validation Images Shape:  (10000, 32, 32, 3)
# Validation Labels Shape:  (10000, 1)
#
# Test Images Shape:        (10000, 32, 32, 3)
# Test Labels Shape:        (10000, 1)

# %%
# CIFAR-10 classes
lables = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
               
# Create a new figure
plt.figure(figsize=(15,15))

# Loop over the first 25 images
for i in range(64):
    # Create a subplot for each image
    plt.subplot(8, 8, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)

    # Display the image
    plt.imshow(X_train[i])

    # Set the label as the title
    plt.title(lables[y_train[i][0]], fontsize=12)

# Display the figure
plt.show()

# %%
classes_name = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

classes, counts = np.unique(y_train, return_counts=True)
plt.barh(classes_name, counts)
plt.title('Class distribution in training set')
# Out:
# Text(0.5, 1.0, 'Class distribution in training set')

# %%
classes, counts = np.unique(y_test, return_counts=True)
plt.barh(classes_name, counts)
plt.title('Class distribution in testing set')
# Out:
# Text(0.5, 1.0, 'Class distribution in testing set')

# %%
# Normalize pixel values to [0, 1]
X_train = X_train.astype('float32') / 255.0
X_val = X_val.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# Print shapes to verify
print(f"X_train shape: {X_train.shape}")
print(f"X_val shape: {X_val.shape}")
print(f"X_test shape: {X_test.shape}")
# Out:
# X_train shape: (40000, 32, 32, 3)
# X_val shape: (10000, 32, 32, 3)
# X_test shape: (10000, 32, 32, 3)

# %%
# Transform target variable into one-hotencoding
y_category_train = to_categorical(y_train, 10)
y_category_val = to_categorical(y_val, 10)
y_category_test = to_categorical(y_test, 10)

# %%
INPUT_SHAPE = (32, 32, 3)
KERNEL_SIZE = (3, 3)
model = Sequential()

# Convolutional Layer
model.add(Conv2D(filters=32, kernel_size=KERNEL_SIZE, input_shape=INPUT_SHAPE, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(filters=32, kernel_size=KERNEL_SIZE, activation='relu', padding='same'))
model.add(BatchNormalization())
# Pooling layer
model.add(MaxPool2D(pool_size=(2, 2)))
# Dropout layers
model.add(Dropout(0.25))

model.add(Conv2D(filters=64, kernel_size=KERNEL_SIZE, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(filters=64, kernel_size=KERNEL_SIZE, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(filters=128, kernel_size=KERNEL_SIZE, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(filters=128, kernel_size=KERNEL_SIZE, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
# model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(10, activation='softmax'))

# Define optimizer with specific learning rate
optimizer = tf.keras.optimizers.Adam(learning_rate=0.005)

# Compile the model with the updated optimizer
METRICS = [
    'accuracy',
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall')
]
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=METRICS)

# %%
data_generator = ImageDataGenerator(
    width_shift_range=0.1,

    rotation_range=10,

    # zoom_range=0.1,

    # brightness_range=[0.9,1.1],

    # shear_range=10,

    # channel_shift_range=0.1,

    height_shift_range=0.1, 

    horizontal_flip=True    
)

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)

# %%
batch_size = 32
train_generator = data_generator.flow(X_train, y_category_train, batch_size)
steps_per_epoch = X_train.shape[0] // batch_size

Eval = model.fit(train_generator, 
                 epochs=50,
                 steps_per_epoch=steps_per_epoch,
                 validation_data=(X_val, y_category_val), 
                 callbacks=[early_stop]
               )
# Out:
# Epoch 1/50
# 1250/1250 [==============================] - 134s 105ms/step - loss: 1.9513 - accuracy: 0.2711 - precision: 0.4867 - recall: 0.0644 - val_loss: 1.5915 - val_accuracy: 0.4011 - val_precision: 0.6566 - val_recall: 0.1348
# Epoch 2/50
# 1250/1250 [==============================] - 127s 101ms/step - loss: 1.5834 - accuracy: 0.4100 - precision: 0.6212 - recall: 0.2023 - val_loss: 1.2714 - val_accuracy: 0.5408 - val_precision: 0.6997 - val_recall: 0.3926
# Epoch 3/50
# 1250/1250 [==============================] - 128s 103ms/step - loss: 1.3391 - accuracy: 0.5237 - precision: 0.6972 - recall: 0.3419 - val_loss: 1.1601 - val_accuracy: 0.5868 - val_precision: 0.7154 - val_recall: 0.4569
# Epoch 4/50
# 1250/1250 [==============================] - 130s 104ms/step - loss: 1.1789 - accuracy: 0.5886 - precision: 0.7433 - recall: 0.4370 - val_loss: 1.4701 - val_accuracy: 0.5737 - val_precision: 0.6553 - val_recall: 0.5151
# Epoch 5/50
# 1250/1250 [==============================] - 129s 103ms/step - loss: 1.0900 - accuracy: 0.6252 - precision: 0.7629 - recall: 0.4879 - val_loss: 1.0544 - val_accuracy: 0.6517 - val_precision: 0.7614 - val_recall: 0.5511
# Epoch 6/50
# 1250/1250 [==============================] - 122s 98ms/step - loss: 1.0204 - accuracy: 0.6483 - precision: 0.7804 - recall: 0.5221 - val_loss: 1.1610 - val_accuracy: 0.6438 - val_precision: 0.7375 - val_recall: 0.5690
# Epoch 7/50
# 1250/1250 [==============================] - 119s 95ms/step - loss: 0.9834 - accuracy: 0.6656 - precision: 0.7875 - recall: 0.5491 - val_loss: 0.8611 - val_accuracy: 0.7098 - val_precision: 0.8161 - val_recall: 0.6072
# Epoch 8/50
# 1250/1250 [==============================] - 115s 92ms/step - loss: 0.9435 - accuracy: 0.6814 - precision: 0.8011 - recall: 0.5696 - val_loss: 1.0347 - val_accuracy: 0.6619 - val_precision: 0.7597 - val_recall: 0.5843
# Epoch 9/50
# 1250/1250 [==============================] - 123s 99ms/step - loss: 0.9215 - accuracy: 0.6901 - precision: 0.8050 - recall: 0.5821 - val_loss: 0.8760 - val_accuracy: 0.7159 - val_precision: 0.8065 - val_recall: 0.6413
# Epoch 10/50
# 1250/1250 [==============================] - 117s 93ms/step - loss: 0.8976 - accuracy: 0.6967 - precision: 0.8088 - recall: 0.5936 - val_loss: 0.8283 - val_accuracy: 0.7373 - val_precision: 0.8073 - val_recall: 0.6679
# Epoch 11/50
# 1250/1250 [==============================] - 116s 93ms/step - loss: 0.8720 - accuracy: 0.7093 - precision: 0.8156 - recall: 0.6096 - val_loss: 0.8193 - val_accuracy: 0.7401 - val_precision: 0.8283 - val_recall: 0.6467
# Epoch 12/50
# 1250/1250 [==============================] - 116s 93ms/step - loss: 0.8542 - accuracy: 0.7154 - precision: 0.8214 - recall: 0.6173 - val_loss: 0.8605 - val_accuracy: 0.7281 - val_precision: 0.8066 - val_recall: 0.6605
# Epoch 13/50
# 1250/1250 [==============================] - 116s 93ms/step - loss: 0.8433 - accuracy: 0.7162 - precision: 0.8238 - recall: 0.6216 - val_loss: 0.9928 - val_accuracy: 0.6944 - val_precision: 0.7839 - val_recall: 0.6149
# Epoch 14/50
# 1250/1250 [==============================] - 117s 94ms/step - loss: 0.8232 - accuracy: 0.7258 - precision: 0.8278 - recall: 0.6328 - val_loss: 0.7558 - val_accuracy: 0.7578 - val_precision: 0.8387 - val_recall: 0.6939
# Epoch 15/50
# 1250/1250 [==============================] - 120s 96ms/step - loss: 0.8136 - accuracy: 0.7295 - precision: 0.8304 - recall: 0.6395 - val_loss: 0.8455 - val_accuracy: 0.7297 - val_precision: 0.8146 - val_recall: 0.6568
# Epoch 16/50
# 1250/1250 [==============================] - 115s 92ms/step - loss: 0.7969 - accuracy: 0.7358 - precision: 0.8352 - recall: 0.6489 - val_loss: 0.7310 - val_accuracy: 0.7593 - val_precision: 0.8462 - val_recall: 0.6878
# Epoch 17/50
# 1250/1250 [==============================] - 118s 94ms/step - loss: 0.7892 - accuracy: 0.7383 - precision: 0.8376 - recall: 0.6501 - val_loss: 0.7047 - val_accuracy: 0.7741 - val_precision: 0.8499 - val_recall: 0.7169
# Epoch 18/50
# 1250/1250 [==============================] - 117s 93ms/step - loss: 0.7830 - accuracy: 0.7402 - precision: 0.8357 - recall: 0.6546 - val_loss: 0.6619 - val_accuracy: 0.7922 - val_precision: 0.8599 - val_recall: 0.7312
# Epoch 19/50
# 1250/1250 [==============================] - 117s 93ms/step - loss: 0.7734 - accuracy: 0.7477 - precision: 0.8384 - recall: 0.6593 - val_loss: 0.8548 - val_accuracy: 0.7325 - val_precision: 0.8180 - val_recall: 0.6669
# Epoch 20/50
# 1250/1250 [==============================] - 117s 93ms/step - loss: 0.7557 - accuracy: 0.7495 - precision: 0.8389 - recall: 0.6675 - val_loss: 0.7804 - val_accuracy: 0.7572 - val_precision: 0.8364 - val_recall: 0.6879
# Epoch 21/50
# 1250/1250 [==============================] - 116s 93ms/step - loss: 0.7566 - accuracy: 0.7486 - precision: 0.8412 - recall: 0.6672 - val_loss: 0.6853 - val_accuracy: 0.7780 - val_precision: 0.8601 - val_recall: 0.7065
# Epoch 22/50
# 1250/1250 [==============================] - 117s 93ms/step - loss: 0.7482 - accuracy: 0.7524 - precision: 0.8442 - recall: 0.6728 - val_loss: 0.6660 - val_accuracy: 0.7857 - val_precision: 0.8598 - val_recall: 0.7238
# Epoch 23/50
# 1250/1250 [==============================] - 119s 95ms/step - loss: 0.7362 - accuracy: 0.7581 - precision: 0.8472 - recall: 0.6751 - val_loss: 0.8018 - val_accuracy: 0.7557 - val_precision: 0.8305 - val_recall: 0.6885
# Epoch 24/50
# 1250/1250 [==============================] - 116s 93ms/step - loss: 0.7323 - accuracy: 0.7598 - precision: 0.8467 - recall: 0.6813 - val_loss: 0.7125 - val_accuracy: 0.7815 - val_precision: 0.8500 - val_recall: 0.7231
# Epoch 25/50
# 1250/1250 [==============================] - 116s 93ms/step - loss: 0.7255 - accuracy: 0.7622 - precision: 0.8499 - recall: 0.6830 - val_loss: 0.6617 - val_accuracy: 0.7893 - val_precision: 0.8537 - val_recall: 0.7449
# Epoch 26/50
# 1250/1250 [==============================] - 117s 93ms/step - loss: 0.7261 - accuracy: 0.7616 - precision: 0.8495 - recall: 0.6842 - val_loss: 0.7563 - val_accuracy: 0.7774 - val_precision: 0.8367 - val_recall: 0.7311
# Epoch 27/50
# 1250/1250 [==============================] - 117s 94ms/step - loss: 0.7145 - accuracy: 0.7666 - precision: 0.8510 - recall: 0.6884 - val_loss: 0.5718 - val_accuracy: 0.8132 - val_precision: 0.8741 - val_recall: 0.7575
# Epoch 28/50
# 1250/1250 [==============================] - 118s 94ms/step - loss: 0.7041 - accuracy: 0.7685 - precision: 0.8521 - recall: 0.6936 - val_loss: 0.7606 - val_accuracy: 0.7742 - val_precision: 0.8387 - val_recall: 0.7126
# Epoch 29/50
# 1250/1250 [==============================] - 116s 93ms/step - loss: 0.7011 - accuracy: 0.7697 - precision: 0.8513 - recall: 0.6928 - val_loss: 0.6277 - val_accuracy: 0.8062 - val_precision: 0.8618 - val_recall: 0.7595
# Epoch 30/50
# 1250/1250 [==============================] - 118s 94ms/step - loss: 0.6907 - accuracy: 0.7732 - precision: 0.8552 - recall: 0.6995 - val_loss: 0.7140 - val_accuracy: 0.7800 - val_precision: 0.8489 - val_recall: 0.7134
# Epoch 31/50
# 1250/1250 [==============================] - 119s 95ms/step - loss: 0.6870 - accuracy: 0.7724 - precision: 0.8549 - recall: 0.7006 - val_loss: 0.6057 - val_accuracy: 0.8098 - val_precision: 0.8619 - val_recall: 0.7671
# Epoch 32/50
# 1250/1250 [==============================] - 117s 94ms/step - loss: 0.6956 - accuracy: 0.7720 - precision: 0.8565 - recall: 0.6981 - val_loss: 0.5832 - val_accuracy: 0.8164 - val_precision: 0.8754 - val_recall: 0.7602
# Epoch 33/50
# 1250/1250 [==============================] - 117s 93ms/step - loss: 0.6811 - accuracy: 0.7772 - precision: 0.8590 - recall: 0.7039 - val_loss: 0.6515 - val_accuracy: 0.8022 - val_precision: 0.8493 - val_recall: 0.7622
# Epoch 34/50
# 1250/1250 [==============================] - 115s 92ms/step - loss: 0.6822 - accuracy: 0.7769 - precision: 0.8577 - recall: 0.7044 - val_loss: 0.5683 - val_accuracy: 0.8202 - val_precision: 0.8795 - val_recall: 0.7737
# Epoch 35/50
# 1250/1250 [==============================] - 116s 92ms/step - loss: 0.6747 - accuracy: 0.7786 - precision: 0.8597 - recall: 0.7073 - val_loss: 0.6072 - val_accuracy: 0.8155 - val_precision: 0.8656 - val_recall: 0.7749
# Epoch 36/50
# 1250/1250 [==============================] - 117s 93ms/step - loss: 0.6744 - accuracy: 0.7799 - precision: 0.8598 - recall: 0.7080 - val_loss: 0.6186 - val_accuracy: 0.8086 - val_precision: 0.8635 - val_recall: 0.7666
# Epoch 37/50
# 1250/1250 [==============================] - 116s 93ms/step - loss: 0.6712 - accuracy: 0.7822 - precision: 0.8648 - recall: 0.7108 - val_loss: 0.6487 - val_accuracy: 0.8055 - val_precision: 0.8715 - val_recall: 0.7521
# Epoch 38/50
# 1250/1250 [==============================] - 118s 94ms/step - loss: 0.6614 - accuracy: 0.7832 - precision: 0.8615 - recall: 0.7128 - val_loss: 0.5479 - val_accuracy: 0.8262 - val_precision: 0.8852 - val_recall: 0.7813
# Epoch 39/50
# 1250/1250 [==============================] - 117s 94ms/step - loss: 0.6593 - accuracy: 0.7840 - precision: 0.8633 - recall: 0.7144 - val_loss: 0.5620 - val_accuracy: 0.8262 - val_precision: 0.8825 - val_recall: 0.7774
# Epoch 40/50
# 1250/1250 [==============================] - 116s 93ms/step - loss: 0.6639 - accuracy: 0.7840 - precision: 0.8605 - recall: 0.7139 - val_loss: 0.6643 - val_accuracy: 0.8063 - val_precision: 0.8503 - val_recall: 0.7688
# Epoch 41/50
# 1250/1250 [==============================] - 115s 92ms/step - loss: 0.6590 - accuracy: 0.7844 - precision: 0.8626 - recall: 0.7154 - val_loss: 0.5558 - val_accuracy: 0.8236 - val_precision: 0.8840 - val_recall: 0.7668
# Epoch 42/50
# 1250/1250 [==============================] - 115s 92ms/step - loss: 0.6540 - accuracy: 0.7875 - precision: 0.8628 - recall: 0.7179 - val_loss: 0.6077 - val_accuracy: 0.8135 - val_precision: 0.8687 - val_recall: 0.7719
# Epoch 43/50
# 1250/1250 [==============================] - 116s 93ms/step - loss: 0.6450 - accuracy: 0.7876 - precision: 0.8645 - recall: 0.7215 - val_loss: 0.6473 - val_accuracy: 0.7949 - val_precision: 0.8690 - val_recall: 0.7325
# Epoch 44/50
# 1250/1250 [==============================] - 134s 107ms/step - loss: 0.6467 - accuracy: 0.7873 - precision: 0.8648 - recall: 0.7223 - val_loss: 0.6302 - val_accuracy: 0.8203 - val_precision: 0.8673 - val_recall: 0.7775
# Epoch 45/50
# 1250/1250 [==============================] - 124s 99ms/step - loss: 0.6530 - accuracy: 0.7876 - precision: 0.8675 - recall: 0.7198 - val_loss: 0.5748 - val_accuracy: 0.8184 - val_precision: 0.8913 - val_recall: 0.7550
# Epoch 46/50
# 1250/1250 [==============================] - 136s 109ms/step - loss: 0.6502 - accuracy: 0.7890 - precision: 0.8660 - recall: 0.7199 - val_loss: 0.5881 - val_accuracy: 0.8259 - val_precision: 0.8705 - val_recall: 0.7912
# Epoch 47/50
# 1250/1250 [==============================] - 134s 107ms/step - loss: 0.6377 - accuracy: 0.7933 - precision: 0.8681 - recall: 0.7265 - val_loss: 0.6102 - val_accuracy: 0.8171 - val_precision: 0.8805 - val_recall: 0.7630
# Epoch 48/50
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6389 - accuracy: 0.7928 - precision: 0.8664 - recall: 0.7263Restoring model weights from the end of the best epoch: 38.
# 1250/1250 [==============================] - 136s 109ms/step - loss: 0.6389 - accuracy: 0.7928 - precision: 0.8664 - recall: 0.7263 - val_loss: 0.6081 - val_accuracy: 0.8044 - val_precision: 0.8760 - val_recall: 0.7424
# Epoch 48: early stopping

# %%
# Calculate F1 score for training and validation
f1_train = [
    2 * (p * r) / (p + r) if (p + r) > 0 else 0 
    for p, r in zip(Eval.history['precision'], Eval.history['recall'])
]
f1_val = [
    2 * (p * r) / (p + r) if (p + r) > 0 else 0 
    for p, r in zip(Eval.history['val_precision'], Eval.history['val_recall'])
]

# Plotting
plt.figure(figsize=(12, 16))

# Loss plot
plt.subplot(4, 2, 1)
plt.plot(Eval.history['loss'], label='Loss')
plt.plot(Eval.history['val_loss'], label='val_Loss')
plt.title('Loss Function Evolution')
plt.legend()

# Accuracy plot
plt.subplot(4, 2, 2)
plt.plot(Eval.history['accuracy'], label='accuracy')
plt.plot(Eval.history['val_accuracy'], label='val_accuracy')
plt.title('Accuracy Function Evolution')
plt.legend()

# Precision plot
plt.subplot(4, 2, 3)
plt.plot(Eval.history['precision'], label='precision')
plt.plot(Eval.history['val_precision'], label='val_precision')
plt.title('Precision Function Evolution')
plt.legend()

# Recall plot
plt.subplot(4, 2, 4)
plt.plot(Eval.history['recall'], label='recall')
plt.plot(Eval.history['val_recall'], label='val_recall')
plt.title('Recall Function Evolution')
plt.legend()

# F1 Score plot
plt.subplot(4, 2, 5)
plt.plot(f1_train, label='F1 Score')
plt.plot(f1_val, label='val_F1 Score')
plt.title('F1 Score Evolution')
plt.legend()

plt.tight_layout()
plt.show()

# %%
evaluation = model.evaluate(X_test, y_category_test)
print(f'Test Accuracy : {evaluation[1] * 100:.2f}%')

y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(y_test, y_pred)


disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=lables)


# NOTE: Fill all variables here with default values of the plot_confusion_matrix
fig, ax = plt.subplots(figsize=(10, 10))
disp = disp.plot(xticks_rotation='vertical', ax=ax,cmap='inferno')

plt.show()
# Out:
# 313/313 [==============================] - 7s 22ms/step - loss: 0.5673 - accuracy: 0.8207 - precision: 0.8811 - recall: 0.7752
# Test Accuracy : 82.07%
# 313/313 [==============================] - 7s 21ms/step

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.83      1000
#            1       0.93      0.93      0.93      1000
#            2       0.78      0.72      0.75      1000
#            3       0.69      0.65      0.67      1000
#            4       0.78      0.83      0.81      1000
#            5       0.87      0.62      0.72      1000
#            6       0.82      0.87      0.84      1000
#            7       0.78      0.90      0.84      1000
#            8       0.90      0.91      0.91      1000
#            9       0.88      0.90      0.89      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.82      0.82      0.82     10000
# weighted avg       0.82      0.82      0.82     10000

# %%
my_image = X_test[50]
plt.imshow(my_image)

# that's a Deer
print(f" Image 50 is {y_test[50]}")

# correctly predicted as a Deer
pred_100 = np.argmax(model.predict(my_image.reshape(1, 32, 32, 3)))
print(f"The model predict that image 50 is {pred_100}")
# Out:
#  Image 50 is [9]
# 1/1 [==============================] - 0s 23ms/step
# The model predict that image 50 is 9

# %%
# CIFAR-10 classes
lables = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
               
# Create a new figure
plt.figure(figsize=(15,15))

# Loop over the first 25 images
for i in range(64):
    # Create a subplot for each image
    plt.subplot(8, 8, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)

    # Display the image
    plt.imshow(X_test[i])

    # Set the label as the title
    plt.title(lables[y_test[i][0]], fontsize=12)

# Display the figure
plt.show()

# %%
def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array, true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel(f"{lables[int(predicted_label)]} {100*np.max(predictions_array):2.0f}% ({lables[int(true_label)]})", 
               color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array, int(true_label[i])
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %%
predictions = model.predict(X_test)

# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 8
num_cols = 5
num_images = num_rows * num_cols
plt.figure(figsize=(2 * 2 * num_cols, 2 * num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2 * num_cols, 2 * i + 1)
    plot_image(i, predictions[i], y_test, X_test)
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i, predictions[i], y_test)
plt.tight_layout()
plt.show()
# Out:
# 313/313 [==============================] - 6s 20ms/step
