# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow
from tensorflow.keras.datasets import cifar10
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.models import load_model

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
# Split the training set into 80% training and 20% validation
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# %%
print('Train Images Shape:      ', X_train.shape)
print('Train Labels Shape:      ', y_train.shape)

print('\nValidation Images Shape: ', X_val.shape)
print('Validation Labels Shape: ', y_val.shape)

print('\nTest Images Shape:       ', X_test.shape)
print('Test Labels Shape:       ', y_test.shape)
# Out:
# Train Images Shape:       (40000, 32, 32, 3)
# Train Labels Shape:       (40000, 1)
#
# Validation Images Shape:  (10000, 32, 32, 3)
# Validation Labels Shape:  (10000, 1)
#
# Test Images Shape:        (10000, 32, 32, 3)
# Test Labels Shape:        (10000, 1)

# %%
# CIFAR-10 classes
lables = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
               
# Create a new figure
plt.figure(figsize=(15,15))

# Loop over the first 25 images
for i in range(64):
    # Create a subplot for each image
    plt.subplot(8, 8, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)

    # Display the image
    plt.imshow(X_train[i])

    # Set the label as the title
    plt.title(lables[y_train[i][0]], fontsize=12)

# Display the figure
plt.show()

# %%
classes_name = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

classes, counts = np.unique(y_train, return_counts=True)
plt.barh(classes_name, counts)
plt.title('Class distribution in training set')
# Out:
# Text(0.5, 1.0, 'Class distribution in training set')

# %%
classes, counts = np.unique(y_test, return_counts=True)
plt.barh(classes_name, counts)
plt.title('Class distribution in testing set')
# Out:
# Text(0.5, 1.0, 'Class distribution in testing set')

# %%
# Normalize pixel values to [0, 1]
X_train = X_train.astype('float32') / 255.0
X_val = X_val.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# Print shapes to verify
print(f"X_train shape: {X_train.shape}")
print(f"X_val shape: {X_val.shape}")
print(f"X_test shape: {X_test.shape}")
# Out:
# X_train shape: (40000, 32, 32, 3)
# X_val shape: (10000, 32, 32, 3)
# X_test shape: (10000, 32, 32, 3)

# %%
# Transform target variable into one-hotencoding
y_category_train = to_categorical(y_train, 10)
y_category_val = to_categorical(y_val, 10)
y_category_test = to_categorical(y_test, 10)

# %%
INPUT_SHAPE = (32, 32, 3)
KERNEL_SIZE = (3, 3)
model = Sequential()

# Convolutional Layer
model.add(Conv2D(filters=32, kernel_size=KERNEL_SIZE, input_shape=INPUT_SHAPE, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(filters=32, kernel_size=KERNEL_SIZE, input_shape=INPUT_SHAPE, activation='relu', padding='same'))
model.add(BatchNormalization())
# Pooling layer
model.add(MaxPool2D(pool_size=(2, 2)))
# Dropout layers
model.add(Dropout(0.25))

model.add(Conv2D(filters=64, kernel_size=KERNEL_SIZE, input_shape=INPUT_SHAPE, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(filters=64, kernel_size=KERNEL_SIZE, input_shape=INPUT_SHAPE, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(filters=128, kernel_size=KERNEL_SIZE, input_shape=INPUT_SHAPE, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(filters=128, kernel_size=KERNEL_SIZE, input_shape=INPUT_SHAPE, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
# model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(10, activation='softmax'))

METRICS = [
    'accuracy',
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall')
]
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=METRICS)

# %%
data_generator = ImageDataGenerator(
    width_shift_range=0.1,

    rotation_range=10,

    # zoom_range=0.1,

    # brightness_range=[0.9,1.1],

    # shear_range=10,

    # channel_shift_range=0.1,

    height_shift_range=0.1, 

    horizontal_flip=True    
)

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)

# %%
batch_size = 32
train_generator = data_generator.flow(X_train, y_category_train, batch_size)
steps_per_epoch = X_train.shape[0] // batch_size

Eval = model.fit(train_generator, 
                 epochs=50,
                 steps_per_epoch=steps_per_epoch,
                 validation_data=(X_val, y_category_val), 
                 callbacks=[early_stop]
               )
# Out:
# Epoch 1/50
# 1250/1250 [==============================] - 136s 106ms/step - loss: 1.6771 - accuracy: 0.3932 - precision: 0.5940 - recall: 0.1752 - val_loss: 1.6008 - val_accuracy: 0.4296 - val_precision: 0.5370 - val_recall: 0.3141
# Epoch 2/50
# 1250/1250 [==============================] - 135s 108ms/step - loss: 1.3161 - accuracy: 0.5329 - precision: 0.7056 - recall: 0.3543 - val_loss: 1.1248 - val_accuracy: 0.6012 - val_precision: 0.7337 - val_recall: 0.4810
# Epoch 3/50
# 1250/1250 [==============================] - 132s 106ms/step - loss: 1.1215 - accuracy: 0.6052 - precision: 0.7519 - recall: 0.4589 - val_loss: 1.4337 - val_accuracy: 0.5400 - val_precision: 0.6873 - val_recall: 0.4394
# Epoch 4/50
# 1250/1250 [==============================] - 132s 106ms/step - loss: 1.0183 - accuracy: 0.6503 - precision: 0.7774 - recall: 0.5219 - val_loss: 1.0063 - val_accuracy: 0.6841 - val_precision: 0.7702 - val_recall: 0.6046
# Epoch 5/50
# 1250/1250 [==============================] - 134s 107ms/step - loss: 0.9417 - accuracy: 0.6797 - precision: 0.7945 - recall: 0.5617 - val_loss: 0.8850 - val_accuracy: 0.7023 - val_precision: 0.7988 - val_recall: 0.6155
# Epoch 6/50
# 1250/1250 [==============================] - 131s 104ms/step - loss: 0.8846 - accuracy: 0.6988 - precision: 0.8046 - recall: 0.5929 - val_loss: 1.0102 - val_accuracy: 0.6638 - val_precision: 0.7580 - val_recall: 0.5812
# Epoch 7/50
# 1250/1250 [==============================] - 130s 104ms/step - loss: 0.8379 - accuracy: 0.7129 - precision: 0.8125 - recall: 0.6170 - val_loss: 0.8327 - val_accuracy: 0.7273 - val_precision: 0.7998 - val_recall: 0.6586
# Epoch 8/50
# 1250/1250 [==============================] - 131s 105ms/step - loss: 0.8041 - accuracy: 0.7271 - precision: 0.8219 - recall: 0.6345 - val_loss: 0.6948 - val_accuracy: 0.7697 - val_precision: 0.8356 - val_recall: 0.7093
# Epoch 9/50
# 1250/1250 [==============================] - 132s 106ms/step - loss: 0.7625 - accuracy: 0.7416 - precision: 0.8297 - recall: 0.6593 - val_loss: 0.6430 - val_accuracy: 0.7803 - val_precision: 0.8530 - val_recall: 0.7170
# Epoch 10/50
# 1250/1250 [==============================] - 121s 97ms/step - loss: 0.7337 - accuracy: 0.7503 - precision: 0.8369 - recall: 0.6718 - val_loss: 0.6774 - val_accuracy: 0.7677 - val_precision: 0.8491 - val_recall: 0.7015
# Epoch 11/50
# 1250/1250 [==============================] - 118s 95ms/step - loss: 0.7141 - accuracy: 0.7566 - precision: 0.8408 - recall: 0.6812 - val_loss: 0.7068 - val_accuracy: 0.7693 - val_precision: 0.8323 - val_recall: 0.7199
# Epoch 12/50
# 1250/1250 [==============================] - 119s 95ms/step - loss: 0.6880 - accuracy: 0.7675 - precision: 0.8469 - recall: 0.6932 - val_loss: 0.7561 - val_accuracy: 0.7503 - val_precision: 0.8137 - val_recall: 0.6931
# Epoch 13/50
# 1250/1250 [==============================] - 119s 95ms/step - loss: 0.6705 - accuracy: 0.7756 - precision: 0.8487 - recall: 0.7030 - val_loss: 0.6399 - val_accuracy: 0.7911 - val_precision: 0.8553 - val_recall: 0.7377
# Epoch 14/50
# 1250/1250 [==============================] - 119s 95ms/step - loss: 0.6600 - accuracy: 0.7799 - precision: 0.8526 - recall: 0.7110 - val_loss: 0.5696 - val_accuracy: 0.8072 - val_precision: 0.8660 - val_recall: 0.7554
# Epoch 15/50
# 1250/1250 [==============================] - 120s 96ms/step - loss: 0.6327 - accuracy: 0.7857 - precision: 0.8570 - recall: 0.7197 - val_loss: 0.6295 - val_accuracy: 0.7925 - val_precision: 0.8577 - val_recall: 0.7418
# Epoch 16/50
# 1250/1250 [==============================] - 122s 97ms/step - loss: 0.6178 - accuracy: 0.7890 - precision: 0.8580 - recall: 0.7282 - val_loss: 0.5173 - val_accuracy: 0.8272 - val_precision: 0.8724 - val_recall: 0.7884
# Epoch 17/50
# 1250/1250 [==============================] - 119s 95ms/step - loss: 0.6000 - accuracy: 0.7957 - precision: 0.8621 - recall: 0.7362 - val_loss: 0.5986 - val_accuracy: 0.7993 - val_precision: 0.8578 - val_recall: 0.7591
# Epoch 18/50
# 1250/1250 [==============================] - 120s 96ms/step - loss: 0.5943 - accuracy: 0.8000 - precision: 0.8631 - recall: 0.7410 - val_loss: 0.5555 - val_accuracy: 0.8194 - val_precision: 0.8635 - val_recall: 0.7744
# Epoch 19/50
# 1250/1250 [==============================] - 119s 95ms/step - loss: 0.5754 - accuracy: 0.8045 - precision: 0.8663 - recall: 0.7485 - val_loss: 0.5917 - val_accuracy: 0.8064 - val_precision: 0.8556 - val_recall: 0.7689
# Epoch 20/50
# 1250/1250 [==============================] - 127s 102ms/step - loss: 0.5674 - accuracy: 0.8081 - precision: 0.8689 - recall: 0.7513 - val_loss: 0.5325 - val_accuracy: 0.8226 - val_precision: 0.8612 - val_recall: 0.7925
# Epoch 21/50
# 1250/1250 [==============================] - 132s 105ms/step - loss: 0.5499 - accuracy: 0.8135 - precision: 0.8718 - recall: 0.7603 - val_loss: 0.5324 - val_accuracy: 0.8235 - val_precision: 0.8727 - val_recall: 0.7861
# Epoch 22/50
# 1250/1250 [==============================] - 133s 106ms/step - loss: 0.5406 - accuracy: 0.8142 - precision: 0.8715 - recall: 0.7625 - val_loss: 0.5420 - val_accuracy: 0.8201 - val_precision: 0.8672 - val_recall: 0.7835
# Epoch 23/50
# 1250/1250 [==============================] - 134s 107ms/step - loss: 0.5317 - accuracy: 0.8201 - precision: 0.8758 - recall: 0.7698 - val_loss: 0.5571 - val_accuracy: 0.8215 - val_precision: 0.8618 - val_recall: 0.7898
# Epoch 24/50
# 1250/1250 [==============================] - 132s 105ms/step - loss: 0.5216 - accuracy: 0.8217 - precision: 0.8768 - recall: 0.7725 - val_loss: 0.5043 - val_accuracy: 0.8291 - val_precision: 0.8738 - val_recall: 0.7923
# Epoch 25/50
# 1250/1250 [==============================] - 123s 98ms/step - loss: 0.5174 - accuracy: 0.8228 - precision: 0.8764 - recall: 0.7730 - val_loss: 0.4882 - val_accuracy: 0.8382 - val_precision: 0.8801 - val_recall: 0.8043
# Epoch 26/50
# 1250/1250 [==============================] - 119s 95ms/step - loss: 0.5086 - accuracy: 0.8274 - precision: 0.8797 - recall: 0.7791 - val_loss: 0.4568 - val_accuracy: 0.8460 - val_precision: 0.8835 - val_recall: 0.8140
# Epoch 27/50
# 1250/1250 [==============================] - 120s 96ms/step - loss: 0.5023 - accuracy: 0.8278 - precision: 0.8805 - recall: 0.7818 - val_loss: 0.4422 - val_accuracy: 0.8515 - val_precision: 0.8870 - val_recall: 0.8238
# Epoch 28/50
# 1250/1250 [==============================] - 120s 96ms/step - loss: 0.5008 - accuracy: 0.8281 - precision: 0.8793 - recall: 0.7824 - val_loss: 0.5113 - val_accuracy: 0.8285 - val_precision: 0.8691 - val_recall: 0.7911
# Epoch 29/50
# 1250/1250 [==============================] - 118s 95ms/step - loss: 0.4894 - accuracy: 0.8328 - precision: 0.8816 - recall: 0.7867 - val_loss: 0.5000 - val_accuracy: 0.8344 - val_precision: 0.8816 - val_recall: 0.7991
# Epoch 30/50
# 1250/1250 [==============================] - 120s 96ms/step - loss: 0.4845 - accuracy: 0.8334 - precision: 0.8828 - recall: 0.7897 - val_loss: 0.4503 - val_accuracy: 0.8493 - val_precision: 0.8833 - val_recall: 0.8178
# Epoch 31/50
# 1250/1250 [==============================] - 122s 97ms/step - loss: 0.4727 - accuracy: 0.8372 - precision: 0.8850 - recall: 0.7946 - val_loss: 0.4882 - val_accuracy: 0.8431 - val_precision: 0.8825 - val_recall: 0.8079
# Epoch 32/50
# 1250/1250 [==============================] - 120s 96ms/step - loss: 0.4646 - accuracy: 0.8419 - precision: 0.8884 - recall: 0.8002 - val_loss: 0.4532 - val_accuracy: 0.8448 - val_precision: 0.8873 - val_recall: 0.8099
# Epoch 33/50
# 1250/1250 [==============================] - 120s 96ms/step - loss: 0.4670 - accuracy: 0.8397 - precision: 0.8866 - recall: 0.7969 - val_loss: 0.4782 - val_accuracy: 0.8430 - val_precision: 0.8876 - val_recall: 0.8071
# Epoch 34/50
# 1250/1250 [==============================] - 120s 96ms/step - loss: 0.4592 - accuracy: 0.8444 - precision: 0.8890 - recall: 0.8016 - val_loss: 0.4710 - val_accuracy: 0.8453 - val_precision: 0.8862 - val_recall: 0.8096
# Epoch 35/50
# 1250/1250 [==============================] - 120s 96ms/step - loss: 0.4543 - accuracy: 0.8440 - precision: 0.8898 - recall: 0.8032 - val_loss: 0.4050 - val_accuracy: 0.8681 - val_precision: 0.8971 - val_recall: 0.8440
# Epoch 36/50
# 1250/1250 [==============================] - 120s 96ms/step - loss: 0.4542 - accuracy: 0.8437 - precision: 0.8880 - recall: 0.8033 - val_loss: 0.4818 - val_accuracy: 0.8433 - val_precision: 0.8807 - val_recall: 0.8166
# Epoch 37/50
# 1250/1250 [==============================] - 126s 101ms/step - loss: 0.4506 - accuracy: 0.8465 - precision: 0.8899 - recall: 0.8066 - val_loss: 0.3936 - val_accuracy: 0.8673 - val_precision: 0.9023 - val_recall: 0.8379
# Epoch 38/50
# 1250/1250 [==============================] - 128s 103ms/step - loss: 0.4422 - accuracy: 0.8485 - precision: 0.8920 - recall: 0.8090 - val_loss: 0.5104 - val_accuracy: 0.8355 - val_precision: 0.8743 - val_recall: 0.8036
# Epoch 39/50
# 1250/1250 [==============================] - 129s 103ms/step - loss: 0.4343 - accuracy: 0.8500 - precision: 0.8927 - recall: 0.8119 - val_loss: 0.4400 - val_accuracy: 0.8561 - val_precision: 0.8866 - val_recall: 0.8320
# Epoch 40/50
# 1250/1250 [==============================] - 127s 101ms/step - loss: 0.4326 - accuracy: 0.8525 - precision: 0.8946 - recall: 0.8142 - val_loss: 0.5125 - val_accuracy: 0.8366 - val_precision: 0.8777 - val_recall: 0.8034
# Epoch 41/50
# 1250/1250 [==============================] - 126s 101ms/step - loss: 0.4296 - accuracy: 0.8538 - precision: 0.8959 - recall: 0.8162 - val_loss: 0.4587 - val_accuracy: 0.8541 - val_precision: 0.8829 - val_recall: 0.8290
# Epoch 42/50
# 1250/1250 [==============================] - 125s 100ms/step - loss: 0.4207 - accuracy: 0.8550 - precision: 0.8964 - recall: 0.8205 - val_loss: 0.4637 - val_accuracy: 0.8508 - val_precision: 0.8871 - val_recall: 0.8218
# Epoch 43/50
# 1250/1250 [==============================] - 131s 105ms/step - loss: 0.4166 - accuracy: 0.8559 - precision: 0.8975 - recall: 0.8211 - val_loss: 0.4385 - val_accuracy: 0.8564 - val_precision: 0.8887 - val_recall: 0.8321
# Epoch 44/50
# 1250/1250 [==============================] - 131s 105ms/step - loss: 0.4246 - accuracy: 0.8551 - precision: 0.8973 - recall: 0.8175 - val_loss: 0.4586 - val_accuracy: 0.8601 - val_precision: 0.8852 - val_recall: 0.8402
# Epoch 45/50
# 1250/1250 [==============================] - 134s 107ms/step - loss: 0.4132 - accuracy: 0.8587 - precision: 0.8982 - recall: 0.8214 - val_loss: 0.4446 - val_accuracy: 0.8569 - val_precision: 0.8904 - val_recall: 0.8361
# Epoch 46/50
# 1250/1250 [==============================] - 134s 107ms/step - loss: 0.4139 - accuracy: 0.8565 - precision: 0.8973 - recall: 0.8213 - val_loss: 0.4929 - val_accuracy: 0.8472 - val_precision: 0.8757 - val_recall: 0.8247
# Epoch 47/50
# 1250/1250 [==============================] - ETA: 0s - loss: 0.4083 - accuracy: 0.8604 - precision: 0.8991 - recall: 0.8242Restoring model weights from the end of the best epoch: 37.
# 1250/1250 [==============================] - 129s 103ms/step - loss: 0.4083 - accuracy: 0.8604 - precision: 0.8991 - recall: 0.8242 - val_loss: 0.4020 - val_accuracy: 0.8676 - val_precision: 0.8997 - val_recall: 0.8442
# Epoch 47: early stopping

# %%
evaluation = model.evaluate(X_test, y_category_test)
print(f'Test Accuracy : {evaluation[1] * 100:.2f}%')

y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(y_test, y_pred)


disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=lables)


# NOTE: Fill all variables here with default values of the plot_confusion_matrix
fig, ax = plt.subplots(figsize=(10, 10))
disp = disp.plot(xticks_rotation='vertical', ax=ax,cmap='summer')

plt.show()
# Out:
# 313/313 [==============================] - 6s 19ms/step - loss: 0.4170 - accuracy: 0.8603 - precision: 0.8960 - recall: 0.8318
# Test Accuracy : 86.03%
# 313/313 [==============================] - 6s 19ms/step

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.88      1000
#            1       0.92      0.96      0.94      1000
#            2       0.82      0.79      0.80      1000
#            3       0.74      0.72      0.73      1000
#            4       0.82      0.85      0.83      1000
#            5       0.87      0.72      0.79      1000
#            6       0.82      0.93      0.87      1000
#            7       0.89      0.91      0.90      1000
#            8       0.93      0.92      0.93      1000
#            9       0.92      0.92      0.92      1000
#
#     accuracy                           0.86     10000
#    macro avg       0.86      0.86      0.86     10000
# weighted avg       0.86      0.86      0.86     10000

# %%
my_image = X_test[50]
plt.imshow(my_image)

# that's a Deer
print(f" Image 50 is {y_test[50]}")

# correctly predicted as a Deer
pred_100 = np.argmax(model.predict(my_image.reshape(1, 32, 32, 3)))
print(f"The model predict that image 50 is {pred_100}")
# Out:
#  Image 50 is [9]
# 1/1 [==============================] - 0s 26ms/step
# The model predict that image 50 is 9

# %%
# CIFAR-10 classes
lables = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
               
# Create a new figure
plt.figure(figsize=(15,15))

# Loop over the first 25 images
for i in range(64):
    # Create a subplot for each image
    plt.subplot(8, 8, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)

    # Display the image
    plt.imshow(X_test[i])

    # Set the label as the title
    plt.title(lables[y_test[i][0]], fontsize=12)

# Display the figure
plt.show()

# %%
def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array, true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel(f"{lables[int(predicted_label)]} {100*np.max(predictions_array):2.0f}% ({lables[int(true_label)]})", 
               color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array, int(true_label[i])
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %%
predictions = model.predict(X_test)

# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 8
num_cols = 5
num_images = num_rows * num_cols
plt.figure(figsize=(2 * 2 * num_cols, 2 * num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2 * num_cols, 2 * i + 1)
    plot_image(i, predictions[i], y_test, X_test)
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i, predictions[i], y_test)
plt.tight_layout()
plt.show()
# Out:
# 313/313 [==============================] - 7s 22ms/step

# %%
model.save('cnn_20_epochs.h5')
